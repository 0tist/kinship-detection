# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir())

# Any results you write to the current directory are saved as output.
# Out:
# ['.DS_Store', 'test', 'vgg-face-keras.h5', 'train_relationships.csv', 'README.md', 'One Shot VGG Submission.ipynb', 'model', 'train', '.ipynb_checkpoints', '.git', 'kinship-detection-with-vgg16.ipynb', 'pretrained', 'sample_submission.csv', 'kinship-detection-resnet.ipynb']

# %% [markdown]
# Necassary Imports

# %%
# !pip3 install git+https://github.com/rcmalli/keras-vggface.git
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/rcmalli/keras-vggface.git
#   Cloning https://github.com/rcmalli/keras-vggface.git to /private/var/folders/cn/zwqbqqwj0gx6458jq5vc27vc0000gp/T/pip-req-build-fh7ns4ty
#   Running command git clone -q https://github.com/rcmalli/keras-vggface.git /private/var/folders/cn/zwqbqqwj0gx6458jq5vc27vc0000gp/T/pip-req-build-fh7ns4ty
# Requirement already satisfied (use --upgrade to upgrade): keras-vggface==0.6 from git+https://github.com/rcmalli/keras-vggface.git in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages
# Requirement already satisfied: numpy>=1.9.1 in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras-vggface==0.6) (1.18.1)
# Requirement already satisfied: scipy>=0.14 in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras-vggface==0.6) (1.4.1)
# Requirement already satisfied: h5py in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras-vggface==0.6) (2.10.0)
# Requirement already satisfied: pillow in /Library/Python/3.7/site-packages (from keras-vggface==0.6) (7.0.0)
# Requirement already satisfied: keras in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras-vggface==0.6) (2.3.1)
# Requirement already satisfied: six>=1.9.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/site-packages (from keras-vggface==0.6) (1.12.0)
# Requirement already satisfied: pyyaml in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras-vggface==0.6) (5.3)
# Requirement already satisfied: keras-applications>=1.0.6 in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras->keras-vggface==0.6) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras->keras-vggface==0.6) (1.1.0)
# Building wheels for collected packages: keras-vggface
#   Building wheel for keras-vggface (setup.py) ... done
#   Created wheel for keras-vggface: filename=keras_vggface-0.6-py3-none-any.whl size=8309 sha256=ba1bb9fa072420089c25af03810937a4068bb49effde003985eff63e4ac1b689
#   Stored in directory: /private/var/folders/cn/zwqbqqwj0gx6458jq5vc27vc0000gp/T/pip-ephem-wheel-cache-4rcv28d1/wheels/08/df/86/0225d44647ab2256dbf1e006823288fe9cc86367a056e6ea2c
# Successfully built keras-vggface

# %%
# !pip3 install keras
import h5py
from collections import defaultdict
from glob import glob
from random import choice, sample

import cv2
import numpy as np
import pandas as pd
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Input, Dense, Flatten, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract, Add, Conv2D
from keras.models import Model
from keras.optimizers import Adam
from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace
from keras.applications import resnet50
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (2.3.1)
# Requirement already satisfied: pyyaml in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras) (5.3)
# Requirement already satisfied: scipy>=0.14 in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras) (1.0.8)
# Requirement already satisfied: six>=1.9.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/site-packages (from keras) (1.12.0)
# Requirement already satisfied: h5py in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /Users/jay.0tist/Library/Python/3.7/lib/python/site-packages (from keras) (1.18.1)

# %%
train_file_path = "train_relationships.csv"
train_folders_path = "train/"
val_famillies = "F0009"

# %%
all_images = glob(train_folders_path + "*/*/*.jpg")
all_images
# Out:
# ['train/F0832/MID1/P08797_face2.jpg',
#  'train/F0832/MID1/P08791_face1.jpg',
#  'train/F0832/MID1/P08795_face1.jpg',
#  'train/F0832/MID1/P08793_face1.jpg',
#  'train/F0832/MID1/P08799_face2.jpg',
#  'train/F0832/MID1/P08794_face4.jpg',
#  'train/F0832/MID1/P08792_face1.jpg',
#  'train/F0832/MID2/P08797_face5.jpg',
#  'train/F0832/MID2/P08791_face2.jpg',
#  'train/F0832/MID2/P08793_face5.jpg',
#  'train/F0832/MID2/P08795_face2.jpg',
#  'train/F0832/MID2/P08798_face2.jpg',
#  'train/F0832/MID2/P08800_face1.jpg',
#  'train/F0832/MID2/P08794_face1.jpg',
#  'train/F0832/MID2/P08792_face3.jpg',
#  'train/F0832/MID5/P08797_face4.jpg',
#  'train/F0832/MID5/P08796_face3.jpg',
#  'train/F0832/MID5/P08793_face6.jpg',
#  'train/F0832/MID5/P08792_face4.jpg',
#  'train/F0832/MID4/P08797_face1.jpg',
#  'train/F0832/MID4/P08796_face2.jpg',
#  'train/F0832/MID4/P08798_face1.jpg',
#  'train/F0832/MID4/P08793_face3.jpg',
#  'train/F0832/MID4/P08800_face2.jpg',
#  'train/F0832/MID4/P08794_face3.jpg',
#  'train/F0832/MID4/P08792_face2.jpg',
#  'train/F0832/MID3/P08797_face3.jpg',
#  'train/F0832/MID3/P08796_face1.jpg',
#  'train/F0832/MID3/P08793_face4.jpg',
#  'train/F0832/MID3/P08800_face4.jpg',
#  'train/F0832/MID3/P08794_face2.jpg',
#  'train/F0832/MID3/P08799_face1.jpg',
#  'train/F0832/MID3/P08792_face5.jpg',
#  'train/F0658/MID6/P11016_face4.jpg',
#  'train/F0658/MID1/P11020_face3.jpg',
#  'train/F0658/MID1/P11018_face1.jpg',
#  'train/F0658/MID1/P11021_face2.jpg',
#  'train/F0658/MID1/P11019_face6.jpg',
#  'train/F0658/MID1/P11027_face2.jpg',
#  'train/F0658/MID1/P11022_face3.jpg',
#  'train/F0658/MID1/P11017_face2.jpg',
#  'train/F0658/MID1/P11024_face2.jpg',
#  'train/F0658/MID1/P11023_face2.jpg',
#  'train/F0658/MID1/P11016_face1.jpg',
#  'train/F0658/MID1/P11028_face1.jpg',
#  'train/F0009/MID1/P10576_face2.jpg',
#  'train/F0009/MID1/P11752_face1.jpg',
#  'train/F0009/MID1/P00089_face3.jpg',
#  'train/F0009/MID1/P11723_face2.jpg',
#  'train/F0009/MID1/P10569_face2.jpg',
#  'train/F0009/MID1/P11740_face1.jpg',
#  'train/F0009/MID1/P11730_face1.jpg',
#  'train/F0009/MID1/P10571_face4.jpg',
#  'train/F0009/MID1/P10577_face3.jpg',
#  'train/F0009/MID1/P11753_face1.jpg',
#  'train/F0009/MID1/P11741_face3.jpg',
#  'train/F0009/MID1/P11755_face2.jpg',
#  'train/F0009/MID1/P11724_face4.jpg',
#  'train/F0009/MID1/P11736_face2.jpg',
#  'train/F0009/MID1/P11722_face2.jpg',
#  'train/F0009/MID1/P10588_face2.jpg',
#  'train/F0009/MID1/P11749_face1.jpg',
#  'train/F0009/MID1/P11727_face3.jpg',
#  'train/F0009/MID1/P11750_face1.jpg',
#  'train/F0009/MID1/P10574_face1.jpg',
#  'train/F0009/MID1/P11721_face5.jpg',
#  'train/F0009/MID1/P10572_face2.jpg',
#  'train/F0009/MID1/P11735_face1.jpg',
#  'train/F0009/MID1/P11738_face3.jpg',
#  'train/F0009/MID1/P11714_face1.jpg',
#  'train/F0009/MID1/P11744_face6.jpg',
#  'train/F0009/MID1/P11742_face1.jpg',
#  'train/F0009/MID1/P11719_face1.jpg',
#  'train/F0009/MID1/P11733_face4.jpg',
#  'train/F0009/MID1/P11732_face1.jpg',
#  'train/F0009/MID1/P11748_face1.jpg',
#  'train/F0009/MID1/P11745_face1.jpg',
#  'train/F0009/MID1/P11734_face1.jpg',
#  'train/F0009/MID1/P11757_face3.jpg',
#  'train/F0009/MID1/P10575_face6.jpg',
#  'train/F0009/MID1/P11720_face3.jpg',
#  'train/F0009/MID1/P11726_face4.jpg',
#  'train/F0009/MID7/P10576_face1.jpg',
#  'train/F0009/MID7/P11737_face4.jpg',
#  'train/F0009/MID7/P11736_face1.jpg',
#  'train/F0009/MID7/P11742_face2.jpg',
#  'train/F0009/MID7/P11745_face2.jpg',
#  'train/F0009/MID7/P11743_face5.jpg',
#  'train/F0009/MID7/P11739_face1.jpg',
#  'train/F0009/MID2/P11737_face5.jpg',
#  'train/F0009/MID2/P10570_face6.jpg',
#  'train/F0009/MID2/P00089_face2.jpg',
#  'train/F0009/MID2/P11716_face1.jpg',
#  'train/F0009/MID2/P10569_face1.jpg',
#  'train/F0009/MID2/P11723_face3.jpg',
#  'train/F0009/MID2/P11741_face5.jpg',
#  'train/F0009/MID2/P10577_face1.jpg',
#  'train/F0009/MID2/P11724_face3.jpg',
#  'train/F0009/MID2/P11717_face1.jpg',
#  'train/F0009/MID2/P10571_face2.jpg',
#  'train/F0009/MID2/P11755_face1.jpg',
#  'train/F0009/MID2/P11744_face3.jpg',
#  'train/F0009/MID2/P11733_face3.jpg',
#  'train/F0009/MID2/P10588_face1.jpg',
#  'train/F0009/MID2/P11721_face1.jpg',
#  'train/F0009/MID2/P10572_face1.jpg',
#  'train/F0009/MID2/P11735_face2.jpg',
#  'train/F0009/MID2/P10575_face3.jpg',
#  'train/F0009/MID2/P11757_face5.jpg',
#  'train/F0009/MID2/P11720_face4.jpg',
#  'train/F0009/MID2/P11726_face2.jpg',
#  'train/F0009/MID2/P11715_face1.jpg',
#  'train/F0009/MID2/P11743_face1.jpg',
#  'train/F0009/MID2/P11718_face1.jpg',
#  'train/F0009/MID5/P11752_face2.jpg',
#  'train/F0009/MID5/P11725_face3.jpg',
#  'train/F0009/MID5/P00089_face5.jpg',
#  'train/F0009/MID5/P11753_face2.jpg',
#  'train/F0009/MID5/P11722_face3.jpg',
#  'train/F0009/MID5/P10574_face2.jpg',
#  'train/F0009/MID5/P11744_face2.jpg',
#  'train/F0009/MID5/P11721_face4.jpg',
#  'train/F0009/MID5/P11733_face5.jpg',
#  'train/F0009/MID5/P11738_face1.jpg',
#  'train/F0009/MID5/P11735_face3.jpg',
#  'train/F0009/MID5/P11720_face6.jpg',
#  'train/F0009/MID5/P11751_face1.jpg',
#  'train/F0009/MID5/P10573_face1.jpg',
#  'train/F0009/MID4/P10570_face4.jpg',
#  'train/F0009/MID4/P11723_face1.jpg',
#  'train/F0009/MID4/P11754_face2.jpg',
#  'train/F0009/MID4/P11737_face1.jpg',
#  'train/F0009/MID4/P00089_face4.jpg',
#  'train/F0009/MID4/P11724_face1.jpg',
#  'train/F0009/MID4/P11741_face1.jpg',
#  'train/F0009/MID4/P10571_face1.jpg',
#  'train/F0009/MID4/P11735_face4.jpg',
#  'train/F0009/MID4/P11733_face2.jpg',
#  'train/F0009/MID4/P11744_face1.jpg',
#  'train/F0009/MID4/P10574_face5.jpg',
#  'train/F0009/MID4/P11756_face2.jpg',
#  'train/F0009/MID4/P10588_face4.jpg',
#  'train/F0009/MID4/P11721_face3.jpg',
#  'train/F0009/MID4/P11732_face3.jpg',
#  'train/F0009/MID4/P11743_face3.jpg',
#  'train/F0009/MID4/P11726_face5.jpg',
#  'train/F0009/MID4/P11720_face2.jpg',
#  'train/F0009/MID4/P11757_face1.jpg',
#  'train/F0009/MID3/P00089_face1.jpg',
#  'train/F0009/MID3/P11728_face1.jpg',
#  'train/F0009/MID3/P11746_face1.jpg',
#  'train/F0009/MID3/P11723_face4.jpg',
#  'train/F0009/MID3/P10570_face2.jpg',
#  'train/F0009/MID3/P11737_face2.jpg',
#  'train/F0009/MID3/P11741_face4.jpg',
#  'train/F0009/MID3/P11724_face2.jpg',
#  'train/F0009/MID3/P11729_face1.jpg',
#  'train/F0009/MID3/P11741_face2.jpg',
#  'train/F0009/MID3/P11738_face4.jpg',
#  'train/F0009/MID3/P10588_face3.jpg',
#  'train/F0009/MID3/P11735_face5.jpg',
#  'train/F0009/MID3/P11727_face2.jpg',
#  'train/F0009/MID3/P11744_face5.jpg',
#  'train/F0009/MID3/P11744_face4.jpg',
#  'train/F0009/MID3/P11726_face3.jpg',
#  'train/F0009/MID3/P11743_face6.jpg',
#  'train/F0009/MID3/P11757_face2.jpg',
#  'train/F0036/MID6/P00375_face3.jpg',
#  'train/F0036/MID6/P00381_face3.jpg',
#  'train/F0036/MID1/P00374_face1.jpg',
#  'train/F0036/MID1/P00379_face2.jpg',
#  'train/F0036/MID1/P00375_face6.jpg',
#  'train/F0036/MID1/P00373_face4.jpg',
#  'train/F0036/MID1/P00378_face3.jpg',
#  'train/F0036/MID1/P00381_face2.jpg',
#  'train/F0036/MID1/P00376_face2.jpg',
#  'train/F0036/MID1/P00380_face1.jpg',
#  'train/F0036/MID1/P00377_face2.jpg',
#  'train/F0036/MID7/P00378_face1.jpg',
#  'train/F0036/MID7/P00381_face1.jpg',
#  'train/F0036/MID2/P00372_face1.jpg',
#  'train/F0036/MID2/P00375_face4.jpg',
#  'train/F0036/MID2/P00376_face1.jpg',
#  'train/F0036/MID2/P00377_face1.jpg',
#  'train/F0036/MID5/P00375_face5.jpg',
#  'train/F0036/MID5/P00373_face1.jpg',
#  'train/F0036/MID4/P00373_face2.jpg',
#  'train/F0036/MID4/P00375_face1.jpg',
#  'train/F0036/MID3/P00379_face1.jpg',
#  'train/F0036/MID3/P00373_face3.jpg',
#  'train/F0036/MID3/P00375_face2.jpg',
#  'train/F0036/MID3/P00378_face2.jpg',
#  'train/F0036/MID3/P00381_face4.jpg',
#  'train/F0036/MID3/P00380_face2.jpg',
#  'train/F0452/MID1/P04773_face1.jpg',
#  'train/F0452/MID1/P04775_face1.jpg',
#  'train/F0452/MID1/P04772_face2.jpg',
#  'train/F0452/MID1/P04774_face1.jpg',
#  'train/F0452/MID1/P04771_face2.jpg',
#  'train/F0452/MID2/P04773_face2.jpg',
#  'train/F0452/MID2/P04774_face2.jpg',
#  'train/F0452/MID2/P04771_face1.jpg',
#  'train/F0803/MID1/P08506_face2.jpg',
#  'train/F0803/MID1/P08489_face1.jpg',
#  'train/F0803/MID1/P08490_face2.jpg',
#  'train/F0803/MID1/P08491_face2.jpg',
#  'train/F0803/MID1/P08488_face1.jpg',
#  'train/F0803/MID1/P08501_face2.jpg',
#  'train/F0803/MID1/P08497_face3.jpg',
#  'train/F0803/MID1/P08492_face1.jpg',
#  'train/F0803/MID1/P08499_face4.jpg',
#  'train/F0803/MID1/P08504_face1.jpg',
#  'train/F0803/MID1/P08494_face2.jpg',
#  'train/F0803/MID1/P08493_face2.jpg',
#  'train/F0803/MID1/P08505_face4.jpg',
#  'train/F0803/MID1/P08503_face2.jpg',
#  'train/F0803/MID1/P08487_face4.jpg',
#  'train/F0803/MID2/P08496_face2.jpg',
#  'train/F0803/MID2/P08501_face3.jpg',
#  'train/F0803/MID2/P08497_face2.jpg',
#  'train/F0803/MID2/P08499_face3.jpg',
#  'train/F0803/MID2/P08502_face2.jpg',
#  'train/F0803/MID2/P08505_face3.jpg',
#  'train/F0803/MID2/P08487_face2.jpg',
#  'train/F0803/MID2/P08493_face3.jpg',
#  'train/F0803/MID2/P08498_face2.jpg',
#  'train/F0803/MID4/P08491_face1.jpg',
#  'train/F0803/MID4/P08501_face1.jpg',
#  'train/F0803/MID4/P08492_face2.jpg',
#  'train/F0803/MID4/P08499_face2.jpg',
#  'train/F0803/MID4/P08494_face1.jpg',
#  'train/F0803/MID4/P08495_face1.jpg',
#  'train/F0803/MID3/P08489_face2.jpg',
#  'train/F0803/MID3/P08490_face1.jpg',
#  'train/F0803/MID3/P08506_face1.jpg',
#  'train/F0803/MID3/P08496_face1.jpg',
#  'train/F0803/MID3/P08500_face1.jpg',
#  'train/F0803/MID3/P08501_face5.jpg',
#  'train/F0803/MID3/P08488_face2.jpg',
#  'train/F0803/MID3/P08497_face1.jpg',
#  'train/F0803/MID3/P08504_face2.jpg',
#  'train/F0803/MID3/P08502_face1.jpg',
#  'train/F0803/MID3/P08499_face1.jpg',
#  'train/F0803/MID3/P08493_face1.jpg',
#  'train/F0803/MID3/P08505_face1.jpg',
#  'train/F0803/MID3/P08487_face3.jpg',
#  'train/F0803/MID3/P08498_face1.jpg',
#  'train/F0803/MID3/P08503_face1.jpg',
#  'train/F0669/MID1/P06996_face2.jpg',
#  'train/F0669/MID1/P06989_face1.jpg',
#  'train/F0669/MID1/P06990_face2.jpg',
#  'train/F0669/MID1/P06997_face2.jpg',
#  'train/F0669/MID1/P06991_face1.jpg',
#  'train/F0669/MID1/P06988_face1.jpg',
#  'train/F0669/MID1/P06994_face2.jpg',
#  'train/F0669/MID1/P06992_face1.jpg',
#  'train/F0669/MID1/P06995_face1.jpg',
#  'train/F0669/MID2/P06989_face2.jpg',
#  'train/F0669/MID2/P06990_face1.jpg',
#  'train/F0669/MID2/P06988_face2.jpg',
#  'train/F0669/MID2/P06994_face1.jpg',
#  'train/F0669/MID2/P06992_face3.jpg',
#  'train/F0669/MID4/P06992_face2.jpg',
#  'train/F0669/MID4/P06993_face1.jpg',
#  'train/F0669/MID3/P06996_face1.jpg',
#  'train/F0669/MID3/P06997_face1.jpg',
#  'train/F0669/MID3/P06991_face2.jpg',
#  'train/F0669/MID3/P06995_face2.jpg',
#  'train/F0669/MID3/P06993_face2.jpg',
#  'train/F0656/MID1/P06892_face2.jpg',
#  'train/F0656/MID1/P06894_face2.jpg',
#  'train/F0656/MID1/P06887_face1.jpg',
#  'train/F0656/MID1/P06895_face1.jpg',
#  'train/F0656/MID1/P06889_face1.jpg',
#  'train/F0656/MID1/P06888_face1.jpg',
#  'train/F0656/MID1/P06891_face1.jpg',
#  'train/F0656/MID2/P06892_face3.jpg',
#  'train/F0656/MID2/P06894_face1.jpg',
#  'train/F0656/MID2/P06887_face2.jpg',
#  'train/F0656/MID2/P06895_face2.jpg',
#  'train/F0656/MID2/P06889_face2.jpg',
#  'train/F0656/MID2/P06890_face1.jpg',
#  'train/F0656/MID2/P06891_face2.jpg',
#  'train/F0656/MID2/P06888_face4.jpg',
#  'train/F0656/MID5/P06892_face1.jpg',
#  'train/F0656/MID5/P06887_face3.jpg',
#  'train/F0656/MID5/P06895_face3.jpg',
#  'train/F0656/MID5/P06889_face4.jpg',
#  'train/F0656/MID5/P06888_face5.jpg',
#  'train/F0656/MID4/P06890_face2.jpg',
#  'train/F0656/MID4/P06889_face3.jpg',
#  'train/F0464/MID1/P04901_face1.jpg',
#  'train/F0464/MID1/P04897_face2.jpg',
#  'train/F0464/MID1/P04891_face1.jpg',
#  'train/F0464/MID1/P04900_face2.jpg',
#  'train/F0464/MID1/P04898_face2.jpg',
#  'train/F0464/MID1/P04895_face1.jpg',
#  'train/F0464/MID1/P04893_face1.jpg',
#  'train/F0464/MID1/P04899_face1.jpg',
#  'train/F0464/MID1/P04894_face2.jpg',
#  'train/F0464/MID1/P04902_face1.jpg',
#  'train/F0464/MID2/P04891_face2.jpg',
#  'train/F0464/MID3/P04901_face2.jpg',
#  'train/F0464/MID3/P04897_face1.jpg',
#  'train/F0464/MID3/P04900_face1.jpg',
#  'train/F0464/MID3/P04898_face1.jpg',
#  'train/F0464/MID3/P04895_face2.jpg',
#  'train/F0464/MID3/P04893_face2.jpg',
#  'train/F0464/MID3/P04899_face3.jpg',
#  'train/F0464/MID3/P04894_face1.jpg',
#  'train/F0464/MID3/P04902_face2.jpg',
#  'train/F0038/MID6/P00400_face3.jpg',
#  'train/F0038/MID1/P00400_face2.jpg',
#  'train/F0038/MID1/P00397_face1.jpg',
#  'train/F0038/MID1/P00401_face1.jpg',
#  'train/F0038/MID1/P00396_face3.jpg',
#  'train/F0038/MID1/P00395_face2.jpg',
#  'train/F0038/MID1/P00398_face1.jpg',
#  'train/F0038/MID1/P00404_face1.jpg',
#  'train/F0038/MID1/P00393_face2.jpg',
#  'train/F0038/MID1/P00394_face2.jpg',
#  'train/F0038/MID1/P00399_face1.jpg',
#  'train/F0038/MID1/P00403_face1.jpg',
#  'train/F0038/MID1/P00392_face2.jpg',
#  'train/F0038/MID2/P00397_face2.jpg',
#  'train/F0038/MID2/P00396_face4.jpg',
#  'train/F0038/MID2/P00395_face1.jpg',
#  'train/F0038/MID2/P00402_face1.jpg',
#  'train/F0038/MID2/P00393_face1.jpg',
#  'train/F0038/MID2/P00394_face1.jpg',
#  'train/F0038/MID2/P00399_face2.jpg',
#  'train/F0038/MID2/P00392_face1.jpg',
#  'train/F0038/MID5/P00400_face1.jpg',
#  'train/F0038/MID4/P00401_face2.jpg',
#  'train/F0038/MID4/P00398_face2.jpg',
#  'train/F0038/MID4/P00402_face2.jpg',
#  'train/F0038/MID4/P00399_face3.jpg',
#  'train/F0038/MID3/P00404_face2.jpg',
#  'train/F0038/MID3/P00403_face2.jpg',
#  'train/F0038/MID3/P00394_face3.jpg',
#  'train/F0651/MID1/P06849_face1.jpg',
#  'train/F0651/MID1/P06850_face2.jpg',
#  'train/F0651/MID1/P06851_face1.jpg',
#  'train/F0651/MID1/P06848_face1.jpg',
#  'train/F0651/MID1/P06846_face1.jpg',
#  'train/F0651/MID1/P06852_face1.jpg',
#  'train/F0651/MID1/P06855_face2.jpg',
#  'train/F0651/MID1/P06853_face1.jpg',
#  'train/F0651/MID1/P06847_face1.jpg',
#  'train/F0651/MID2/P06851_face2.jpg',
#  'train/F0651/MID2/P06846_face2.jpg',
#  'train/F0651/MID2/P06855_face1.jpg',
#  'train/F0651/MID2/P06853_face2.jpg',
#  'train/F0651/MID2/P06847_face2.jpg',
#  'train/F0651/MID4/P06849_face2.jpg',
#  'train/F0651/MID3/P06850_face1.jpg',
#  'train/F0651/MID3/P06848_face2.jpg',
#  'train/F0651/MID3/P06852_face2.jpg',
#  'train/F0497/MID1/P05259_face2.jpg',
#  'train/F0497/MID1/P05258_face1.jpg',
#  'train/F0497/MID1/P05256_face1.jpg',
#  'train/F0497/MID1/P05257_face2.jpg',
#  'train/F0497/MID2/P05258_face2.jpg',
#  'train/F0497/MID2/P05260_face2.jpg',
#  'train/F0497/MID2/P05256_face2.jpg',
#  'train/F0497/MID2/P05257_face1.jpg',
#  'train/F0497/MID3/P05259_face1.jpg',
#  'train/F0497/MID3/P05260_face1.jpg',
#  'train/F0408/MID1/P04300_face2.jpg',
#  'train/F0408/MID1/P04297_face3.jpg',
#  'train/F0408/MID1/P04301_face1.jpg',
#  'train/F0408/MID1/P04294_face2.jpg',
#  'train/F0408/MID1/P04299_face2.jpg',
#  'train/F0408/MID1/P04298_face1.jpg',
#  'train/F0408/MID1/P04295_face1.jpg',
#  'train/F0408/MID1/P04303_face3.jpg',
#  'train/F0408/MID2/P04297_face1.jpg',
#  'train/F0408/MID2/P04299_face1.jpg',
#  'train/F0408/MID2/P04294_face1.jpg',
#  'train/F0408/MID2/P04302_face3.jpg',
#  'train/F0408/MID2/P04295_face2.jpg',
#  'train/F0408/MID2/P04303_face1.jpg',
#  'train/F0408/MID2/P04298_face2.jpg',
#  'train/F0408/MID4/P04300_face1.jpg',
#  'train/F0408/MID4/P04301_face2.jpg',
#  'train/F0408/MID4/P04302_face1.jpg',
#  'train/F0408/MID3/P04302_face2.jpg',
#  'train/F0850/MID1/P08980_face2.jpg',
#  'train/F0850/MID1/P08987_face1.jpg',
#  'train/F0850/MID1/P08981_face1.jpg',
#  'train/F0850/MID1/P08989_face1.jpg',
#  'train/F0850/MID1/P08984_face1.jpg',
#  'train/F0850/MID1/P08982_face1.jpg',
#  'train/F0850/MID1/P08988_face1.jpg',
#  'train/F0850/MID1/P08983_face2.jpg',
#  'train/F0850/MID2/P08986_face1.jpg',
#  'train/F0850/MID2/P08980_face1.jpg',
#  'train/F0850/MID2/P08981_face3.jpg',
#  'train/F0850/MID2/P08989_face2.jpg',
#  'train/F0850/MID2/P08984_face4.jpg',
#  'train/F0850/MID2/P08982_face2.jpg',
#  'train/F0850/MID2/P08985_face1.jpg',
#  'train/F0850/MID4/P08980_face3.jpg',
#  'train/F0850/MID4/P08981_face2.jpg',
#  'train/F0850/MID4/P08984_face2.jpg',
#  'train/F0850/MID4/P08982_face3.jpg',
#  'train/F0266/MID1/P02829_face1.jpg',
#  'train/F0266/MID1/P02831_face2.jpg',
#  'train/F0266/MID1/P02825_face1.jpg',
#  'train/F0266/MID1/P02834_face1.jpg',
#  'train/F0266/MID1/P02835_face1.jpg',
#  'train/F0266/MID1/P02833_face2.jpg',
#  'train/F0266/MID1/P02827_face1.jpg',
#  'train/F0266/MID2/P02825_face2.jpg',
#  'train/F0266/MID2/P02834_face2.jpg',
#  'train/F0266/MID2/P02833_face3.jpg',
#  'train/F0868/MID1/P09167_face1.jpg',
#  'train/F0868/MID1/P09173_face1.jpg',
#  'train/F0868/MID1/P09174_face1.jpg',
#  'train/F0868/MID1/P09166_face1.jpg',
#  'train/F0868/MID1/P09172_face2.jpg',
#  'train/F0268/MID2/P02840_face2.jpg',
#  'train/F0268/MID2/P02839_face1.jpg',
#  'train/F0268/MID2/P02842_face2.jpg',
#  'train/F0268/MID2/P02844_face2.jpg',
#  'train/F0866/MID1/P09154_face1.jpg',
#  'train/F0866/MID1/P09146_face1.jpg',
#  'train/F0866/MID1/P09147_face1.jpg',
#  'train/F0866/MID1/P09150_face1.jpg',
#  'train/F0866/MID1/P09151_face1.jpg',
#  'train/F0866/MID1/P09148_face1.jpg',
#  'train/F0866/MID1/P09145_face2.jpg',
#  'train/F0866/MID2/P09154_face2.jpg',
#  'train/F0866/MID2/P09152_face1.jpg',
#  'train/F0866/MID2/P09146_face2.jpg',
#  'train/F0866/MID2/P09147_face2.jpg',
#  'train/F0866/MID2/P09149_face1.jpg',
#  'train/F0866/MID2/P09148_face2.jpg',
#  'train/F0866/MID2/P09145_face1.jpg',
#  'train/F0866/MID2/P09151_face2.jpg',
#  'train/F0892/MID1/P09416_face4.jpg',
#  'train/F0892/MID1/P09417_face1.jpg',
#  'train/F0892/MID1/P09421_face5.jpg',
#  'train/F0892/MID1/P09419_face3.jpg',
#  'train/F0892/MID1/P09414_face2.jpg',
#  'train/F0892/MID1/P09412_face4.jpg',
#  'train/F0892/MID1/P09413_face1.jpg',
#  'train/F0892/MID1/P09418_face2.jpg',
#  'train/F0892/MID1/P09415_face1.jpg',
#  'train/F0892/MID1/P09420_face2.jpg',
#  'train/F0892/MID2/P09416_face3.jpg',
#  'train/F0892/MID2/P09417_face2.jpg',
#  'train/F0892/MID2/P09421_face6.jpg',
#  'train/F0892/MID2/P09412_face3.jpg',
#  'train/F0892/MID2/P09414_face1.jpg',
#  'train/F0892/MID2/P09419_face1.jpg',
#  'train/F0892/MID2/P09415_face7.jpg',
#  'train/F0892/MID2/P09413_face2.jpg',
#  'train/F0892/MID2/P09420_face1.jpg',
#  'train/F0892/MID2/P09418_face1.jpg',
#  'train/F0892/MID4/P09416_face1.jpg',
#  'train/F0892/MID4/P09417_face3.jpg',
#  'train/F0892/MID4/P09421_face7.jpg',
#  'train/F0892/MID4/P09414_face4.jpg',
#  'train/F0892/MID4/P09412_face2.jpg',
#  'train/F0892/MID4/P09419_face2.jpg',
#  'train/F0892/MID4/P09420_face4.jpg',
#  'train/F0892/MID3/P09416_face2.jpg',
#  'train/F0892/MID3/P09417_face4.jpg',
#  'train/F0892/MID3/P09421_face9.jpg',
#  'train/F0892/MID3/P09412_face1.jpg',
#  'train/F0892/MID3/P09414_face3.jpg',
#  'train/F0892/MID3/P09420_face3.jpg',
#  'train/F0805/MID6/P08521_face3.jpg',
#  'train/F0805/MID1/P08521_face5.jpg',
#  'train/F0805/MID1/P08527_face3.jpg',
#  'train/F0805/MID1/P08526_face1.jpg',
#  'train/F0805/MID1/P08520_face2.jpg',
#  'train/F0805/MID1/P08528_face2.jpg',
#  'train/F0805/MID1/P08525_face1.jpg',
#  'train/F0805/MID1/P08523_face1.jpg',
#  'train/F0805/MID1/P08529_face3.jpg',
#  'train/F0805/MID8/P08527_face2.jpg',
#  'train/F0805/MID7/P08527_face4.jpg',
#  'train/F0805/MID7/P08526_face2.jpg',
#  'train/F0805/MID7/P08528_face3.jpg',
#  'train/F0805/MID7/P08524_face2.jpg',
#  'train/F0805/MID2/P08521_face4.jpg',
#  'train/F0805/MID2/P08520_face1.jpg',
#  'train/F0805/MID5/P08521_face6.jpg',
#  'train/F0805/MID5/P08523_face2.jpg',
#  'train/F0805/MID4/P08521_face2.jpg',
#  'train/F0805/MID4/P08529_face1.jpg',
#  'train/F0805/MID3/P08521_face1.jpg',
#  'train/F0805/MID3/P08529_face4.jpg',
#  'train/F0039/MID1/P00406_face1.jpg',
#  'train/F0039/MID1/P00410_face2.jpg',
#  'train/F0039/MID1/P00408_face1.jpg',
#  'train/F0039/MID1/P00405_face1.jpg',
#  'train/F0039/MID4/P00409_face1.jpg',
#  'train/F0039/MID4/P00410_face1.jpg',
#  'train/F0039/MID4/P00408_face2.jpg',
#  'train/F0465/MID1/P04907_face1.jpg',
#  'train/F0465/MID1/P04906_face2.jpg',
#  'train/F0465/MID1/P04905_face1.jpg',
#  'train/F0465/MID1/P04908_face1.jpg',
#  'train/F0465/MID1/P04911_face2.jpg',
#  'train/F0465/MID1/P04910_face1.jpg',
#  'train/F0465/MID1/P04909_face3.jpg',
#  'train/F0465/MID2/P04907_face2.jpg',
#  'train/F0465/MID2/P04906_face1.jpg',
#  'train/F0465/MID2/P04908_face2.jpg',
#  'train/F0465/MID2/P04911_face1.jpg',
#  'train/F0465/MID2/P04905_face2.jpg',
#  'train/F0465/MID2/P04909_face4.jpg',
#  'train/F0465/MID2/P04910_face2.jpg',
#  'train/F0465/MID4/P04909_face1.jpg',
#  'train/F0233/MID6/P02472_face1.jpg',
#  'train/F0233/MID1/P02474_face2.jpg',
#  'train/F0233/MID1/P02473_face1.jpg',
#  'train/F0233/MID1/P02476_face23.jpg',
#  'train/F0233/MID1/P02470_face1.jpg',
#  'train/F0233/MID1/P02469_face1.jpg',
#  'train/F0233/MID1/P02468_face3.jpg',
#  'train/F0233/MID1/P02471_face2.jpg',
#  'train/F0233/MID1/P02477_face2.jpg',
#  'train/F0233/MID2/P02468_face5.jpg',
#  'train/F0233/MID5/P02472_face2.jpg',
#  'train/F0233/MID3/P02475_face1.jpg',
#  'train/F0233/MID3/P02468_face4.jpg',
#  'train/F0491/MID1/P05172_face2.jpg',
#  'train/F0491/MID1/P05175_face1.jpg',
#  'train/F0491/MID1/P05176_face2.jpg',
#  'train/F0491/MID1/P05169_face1.jpg',
#  'train/F0491/MID1/P05170_face1.jpg',
#  'train/F0491/MID1/P05171_face1.jpg',
#  'train/F0491/MID2/P05172_face1.jpg',
#  'train/F0491/MID2/P05178_face1.jpg',
#  'train/F0491/MID2/P05176_face1.jpg',
#  'train/F0491/MID2/P05170_face2.jpg',
#  'train/F0491/MID2/P05169_face2.jpg',
#  'train/F0491/MID2/P05171_face2.jpg',
#  'train/F0491/MID4/P05178_face2.jpg',
#  'train/F0491/MID3/P05174_face1.jpg',
#  'train/F0491/MID3/P05175_face2.jpg',
#  'train/F0491/MID3/P05173_face1.jpg',
#  'train/F0498/MID6/P12100_face2.jpg',
#  'train/F0498/MID6/P12101_face2.jpg',
#  'train/F0498/MID1/P05267_face2.jpg',
#  'train/F0498/MID1/P05261_face1.jpg',
#  'train/F0498/MID1/P12096_face1.jpg',
#  'train/F0498/MID1/P05266_face2.jpg',
#  'train/F0498/MID1/P12101_face3.jpg',
#  'train/F0498/MID1/P12097_face1.jpg',
#  'train/F0498/MID1/P05265_face1.jpg',
#  'train/F0498/MID1/P05268_face2.jpg',
#  'train/F0498/MID1/P05263_face1.jpg',
#  'train/F0498/MID1/P05269_face2.jpg',
#  'train/F0498/MID1/P05264_face2.jpg',
#  'train/F0498/MID1/P05270_face2.jpg',
#  'train/F0498/MID1/P12098_face1.jpg',
#  'train/F0498/MID1/P05262_face1.jpg',
#  'train/F0498/MID1/P12095_face1.jpg',
#  'train/F0498/MID4/P12096_face2.jpg',
#  'train/F0498/MID4/P12095_face2.jpg',
#  'train/F0661/MID1/P06925_face1.jpg',
#  'train/F0661/MID1/P06928_face2.jpg',
#  'train/F0661/MID1/P06923_face2.jpg',
#  'train/F0661/MID1/P06924_face2.jpg',
#  'train/F0661/MID1/P06929_face1.jpg',
#  'train/F0661/MID1/P06922_face1.jpg',
#  'train/F0661/MID1/P06917_face1.jpg',
#  'train/F0661/MID1/P06927_face2.jpg',
#  'train/F0661/MID1/P06921_face1.jpg',
#  'train/F0661/MID1/P06926_face1.jpg',
#  'train/F0661/MID1/P06920_face1.jpg',
#  'train/F0661/MID1/P06915_face2.jpg',
#  'train/F0661/MID1/P06918_face1.jpg',
#  'train/F0661/MID2/P06916_face1.jpg',
#  'train/F0661/MID2/P06923_face3.jpg',
#  'train/F0661/MID2/P06929_face3.jpg',
#  'train/F0661/MID2/P06917_face2.jpg',
#  'train/F0661/MID2/P06922_face3.jpg',
#  'train/F0661/MID2/P06927_face1.jpg',
#  'train/F0661/MID2/P06921_face2.jpg',
#  'train/F0661/MID2/P06926_face2.jpg',
#  'train/F0661/MID2/P06915_face1.jpg',
#  'train/F0661/MID2/P06918_face2.jpg',
#  'train/F0661/MID2/P06920_face3.jpg',
#  'train/F0661/MID4/P06925_face3.jpg',
#  'train/F0661/MID4/P06928_face1.jpg',
#  'train/F0661/MID4/P06924_face1.jpg',
#  'train/F0661/MID4/P06929_face2.jpg',
#  'train/F0661/MID4/P06922_face2.jpg',
#  'train/F0661/MID4/P06917_face3.jpg',
#  'train/F0661/MID4/P06927_face4.jpg',
#  'train/F0661/MID4/P06920_face2.jpg',
#  'train/F0661/MID3/P06916_face2.jpg',
#  'train/F0661/MID3/P06922_face4.jpg',
#  'train/F0661/MID3/P06917_face4.jpg',
#  'train/F0661/MID3/P06929_face4.jpg',
#  'train/F0661/MID3/P06921_face7.jpg',
#  'train/F0661/MID3/P06927_face3.jpg',
#  'train/F0661/MID3/P06919_face1.jpg',
#  'train/F0661/MID3/P06920_face4.jpg',
#  'train/F0695/MID1/P07243_face1.jpg',
#  'train/F0695/MID1/P07239_face1.jpg',
#  'train/F0695/MID1/P07245_face2.jpg',
#  'train/F0695/MID1/P07242_face2.jpg',
#  'train/F0695/MID1/P07244_face2.jpg',
#  'train/F0695/MID1/P07241_face2.jpg',
#  'train/F0695/MID1/P07240_face2.jpg',
#  'train/F0695/MID2/P07238_face2.jpg',
#  'train/F0695/MID5/P07239_face2.jpg',
#  'train/F0695/MID5/P07245_face1.jpg',
#  'train/F0695/MID5/P07242_face1.jpg',
#  'train/F0695/MID5/P07244_face1.jpg',
#  'train/F0695/MID5/P07241_face1.jpg',
#  'train/F0695/MID5/P07240_face1.jpg',
#  'train/F0695/MID4/P07243_face2.jpg',
#  'train/F0695/MID4/P07239_face3.jpg',
#  'train/F0695/MID4/P07242_face3.jpg',
#  'train/F0695/MID3/P07238_face1.jpg',
#  'train/F0833/MID6/P08809_face1.jpg',
#  'train/F0833/MID6/P08808_face1.jpg',
#  'train/F0833/MID1/P08804_face1.jpg',
#  'train/F0833/MID1/P08810_face3.jpg',
#  'train/F0833/MID1/P08802_face2.jpg',
#  'train/F0833/MID1/P08805_face1.jpg',
#  'train/F0833/MID1/P08808_face2.jpg',
#  'train/F0833/MID1/P08803_face1.jpg',
#  'train/F0833/MID1/P08806_face2.jpg',
#  'train/F0833/MID1/P08807_face2.jpg',
#  'train/F0833/MID1/P08801_face2.jpg',
#  'train/F0833/MID2/P08804_face2.jpg',
#  'train/F0833/MID2/P08802_face1.jpg',
#  'train/F0833/MID2/P08810_face4.jpg',
#  'train/F0833/MID2/P08805_face2.jpg',
#  'train/F0833/MID2/P08806_face1.jpg',
#  'train/F0833/MID2/P08801_face1.jpg',
#  'train/F0833/MID5/P08807_face1.jpg',
#  'train/F0833/MID4/P08804_face4.jpg',
#  'train/F0833/MID4/P08803_face2.jpg',
#  'train/F0833/MID3/P08804_face3.jpg',
#  'train/F0833/MID3/P08803_face3.jpg',
#  'train/F0833/MID3/P08806_face3.jpg',
#  'train/F0659/MID1/P06904_face1.jpg',
#  'train/F0659/MID1/P06902_face1.jpg',
#  'train/F0659/MID1/P06903_face1.jpg',
#  'train/F0659/MID1/P06906_face2.jpg',
#  'train/F0659/MID2/P06902_face2.jpg',
#  'train/F0659/MID2/P06906_face1.jpg',
#  'train/F0659/MID2/P06907_face1.jpg',
#  'train/F0030/MID1/P00309_face2.jpg',
#  'train/F0030/MID1/P00310_face4.jpg',
#  'train/F0030/MID1/P00302_face2.jpg',
#  'train/F0030/MID1/P00300_face4.jpg',
#  'train/F0030/MID2/P00305_face1.jpg',
#  'train/F0030/MID2/P00303_face1.jpg',
#  'train/F0030/MID2/P00304_face1.jpg',
#  'train/F0030/MID2/P00307_face2.jpg',
#  'train/F0030/MID2/P00301_face1.jpg',
#  'train/F0030/MID2/P00306_face2.jpg',
#  'train/F0030/MID2/P00300_face1.jpg',
#  'train/F0030/MID4/P00310_face1.jpg',
#  'train/F0030/MID4/P00309_face1.jpg',
#  'train/F0030/MID3/P00308_face1.jpg',
#  'train/F0030/MID3/P00305_face2.jpg',
#  'train/F0030/MID3/P00303_face2.jpg',
#  'train/F0030/MID3/P00304_face2.jpg',
#  'train/F0030/MID3/P00302_face1.jpg',
#  'train/F0030/MID3/P00307_face1.jpg',
#  'train/F0030/MID3/P00301_face2.jpg',
#  'train/F0030/MID3/P00306_face1.jpg',
#  'train/F0202/MID1/P02179_face2.jpg',
#  'train/F0202/MID1/P02174_face1.jpg',
#  'train/F0202/MID1/P02175_face1.jpg',
#  'train/F0202/MID1/P02173_face2.jpg',
#  'train/F0202/MID1/P02182_face1.jpg',
#  'train/F0202/MID1/P02176_face1.jpg',
#  'train/F0202/MID1/P02177_face2.jpg',
#  'train/F0202/MID1/P02180_face3.jpg',
#  'train/F0202/MID2/P02173_face3.jpg',
#  'train/F0202/MID2/P02176_face2.jpg',
#  'train/F0202/MID5/P02179_face1.jpg',
#  'train/F0202/MID5/P02178_face1.jpg',
#  ...]

# %% [markdown]
# Validation set consists only family 9

# %%
train_images = [x for x in all_images if val_famillies not in x]
val_images = [x for x in all_images if val_famillies in x]

# %%
len(val_images)
# Out:
# 151

# %%
train_person_to_images_map = defaultdict(list)

# %%
ppl = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images]
print(ppl)
# Out:
# ['F0832/MID1', 'F0832/MID1', 'F0832/MID1', 'F0832/MID1', 'F0832/MID1', 'F0832/MID1', 'F0832/MID1', 'F0832/MID2', 'F0832/MID2', 'F0832/MID2', 'F0832/MID2', 'F0832/MID2', 'F0832/MID2', 'F0832/MID2', 'F0832/MID2', 'F0832/MID5', 'F0832/MID5', 'F0832/MID5', 'F0832/MID5', 'F0832/MID4', 'F0832/MID4', 'F0832/MID4', 'F0832/MID4', 'F0832/MID4', 'F0832/MID4', 'F0832/MID4', 'F0832/MID3', 'F0832/MID3', 'F0832/MID3', 'F0832/MID3', 'F0832/MID3', 'F0832/MID3', 'F0832/MID3', 'F0658/MID6', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID1', 'F0658/MID7', 'F0658/MID7', 'F0658/MID2', 'F0658/MID2', 'F0658/MID2', 'F0658/MID2', 'F0658/MID2', 'F0658/MID2', 'F0658/MID2', 'F0658/MID2', 'F0658/MID5', 'F0658/MID3', 'F0658/MID3', 'F0658/MID3', 'F0203/MID6', 'F0203/MID1', 'F0203/MID1', 'F0203/MID1', 'F0203/MID1', 'F0203/MID1', 'F0203/MID8', 'F0203/MID7', 'F0203/MID10', 'F0203/MID2', 'F0203/MID5', 'F0203/MID5', 'F0203/MID4', 'F0203/MID3', 'F0031/MID1', 'F0031/MID1', 'F0031/MID1', 'F0031/MID1', 'F0031/MID1', 'F0031/MID1', 'F0031/MID1', 'F0031/MID2', 'F0031/MID2', 'F0031/MID2', 'F0031/MID2', 'F0031/MID2', 'F0031/MID5', 'F0031/MID5', 'F0031/MID5', 'F0031/MID5', 'F0031/MID5', 'F0031/MID5', 'F0031/MID4', 'F0031/MID4', 'F0031/MID4', 'F0031/MID4', 'F0031/MID4', 'F0031/MID4', 'F0031/MID4', 'F0031/MID4', 'F0031/MID4', 'F0031/MID3', 'F0031/MID3', 'F0031/MID
relationships = list(zip(relationships.p1.values, relationships.p2.values))
# for x in relationships:
#     print(x[0])
#     print(x[1])
relationships = [x for x in relationships if x[0] in ppl and x[1] in ppl]
for x in relationships:
    if val_famillies in x[0]:
        print(x)
train = [x for x in relationships if val_famillies not in x[0]]
val = [x for x in relationships if val_famillies in x[0]]

# %%
len(val)
# Out:
# 0

# %%
def read_img(path):
    img = cv2.imread(path)
    img = np.array(img).astype(np.float)
    return preprocess_input(img, version=2)


def gen(list_tuples, person_to_images_map, batch_size=16):
    ppl = list(person_to_images_map.keys())
    while True:
        batch_tuples = sample(list_tuples, batch_size // 2)
        labels = [1] * len(batch_tuples)
        while len(batch_tuples) < batch_size:
            p1 = choice(ppl)
            p2 = choice(ppl)

            if p1 != p2 and (p1, p2) not in list_tuples and (p2, p1) not in list_tuples:
                batch_tuples.append((p1, p2))
                labels.append(0)

        for x in batch_tuples:
            if not len(person_to_images_map[x[0]]):
                print(x[0])

        X1 = [choice(person_to_images_map[x[0]]) for x in batch_tuples]
        X1 = np.array([read_img(x) for x in X1])

        X2 = [choice(person_to_images_map[x[1]]) for x in batch_tuples]
        X2 = np.array([read_img(x) for x in X2])

        yield [X1, X2], labels


def baseline_model():
    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

    base_model = VGGFace(model='resnet50', include_top=False)`

    for layer in base_model.layers[:-3]:
        layer.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)


    merged_add = Add()([x1, x2])
    merged_sub = Subtract()([x1,x2])
    
    merged_add = Conv2D(100 , [1,1] )(merged_add)
    merged_sub = Conv2D(100 , [1,1] )(merged_sub)
    
    merged = Concatenate(axis=-1)([merged_add, merged_sub])
    
    merged = Flatten()(merged)

    merged = Dense(100, activation="relu")(merged)
    merged = Dropout(0.3)(merged)
    merged = Dense(25, activation="relu")(merged)
    merged = Dropout(0.3)(merged)
    out = Dense(1, activation="sigmoid")(merged)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model


file_path = "vgg_face.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

callbacks_list = [checkpoint, reduce_on_plateau]

model = baseline_model()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# vggface_resnet50 (Model)        multiple             23561152    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 1, 1, 2048)   0           vggface_resnet50[1][0]
#                                                                  vggface_resnet50[2][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 1, 1, 2048)   0           vggface_resnet50[1][0]
#                                                                  vggface_resnet50[2][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 1, 1, 100)    204900      add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 1, 100)    204900      subtract_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1, 1, 200)    0           conv2d_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 200)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          20100       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 25)           2525        dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 25)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            26          dropout_2[0][0]
# ==================================================================================================
# Total params: 23,993,603
# Trainable params: 23,940,483
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
bs = 16
model.fit_generator(gen(train, train_person_to_images_map, batch_size=bs), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=130, verbose=1,
                    workers = 1,
                    callbacks=callbacks_list,
                    steps_per_epoch=200,
                    validation_steps=100)
# Out:
# Epoch 1/130
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/jay.0tist/Library/Python/3.7/lib/python/site-packages/keras/utils/data_utils.py", line 650, in next_sample
#     return six.next(_SHARED_SEQUENCES[uid])
#   File "<ipython-input-12-f819a0cfca49>", line 10, in gen
#     batch_tuples = sample(list_tuples, batch_size // 2)
#   File "/usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/random.py", line 321, in sample
#     raise ValueError("Sample larger than population or is negative")
# ValueError: Sample larger than population or is negative
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9055829f314d> in <module>
#       5                     callbacks=callbacks_list,
#       6                     steps_per_epoch=200,
# ----> 7                     validation_steps=len(val_images)/bs)
#
# ~/Library/Python/3.7/lib/python/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/Library/Python/3.7/lib/python/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~/Library/Python/3.7/lib/python/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     183             batch_index = 0
#     184             while steps_done < steps_per_epoch:
# --> 185                 generator_output = next(output_generator)
#     186
#     187                 if not hasattr(generator_output, '__len__'):
#
# ~/Library/Python/3.7/lib/python/site-packages/keras/utils/data_utils.py in get(self)
#     740                     "`use_multiprocessing=False, workers > 1`."
#     741                     "For more information see issue #1638.")
# --> 742             six.reraise(*sys.exc_info())
#
# /usr/local/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     694             if value.__traceback__ is not tb:
#     695                 raise value.with_traceback(tb)
# --> 696             raise value
#     697         finally:
#     698             value = None
#
# ~/Library/Python/3.7/lib/python/site-packages/keras/utils/data_utils.py in get(self)
#     709                 try:
#     710                     future = self.queue.get(block=True)
# --> 711                     inputs = future.get(timeout=30)
#     712                     self.queue.task_done()
#     713                 except mp.TimeoutError:
#
# /usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# ValueError: Sample larger than population or is negative

# %%
test_path = "test/"


def chunker(seq, size=32):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))


from tqdm import tqdm

submission = pd.read_csv('sample_submission.csv')

predictions = []

for batch in tqdm(chunker(submission.img_pair.values)):
    X1 = [x.split("-")[0] for x in batch]
    X1 = np.array([read_img(test_path + x) for x in X1])

    X2 = [x.split("-")[1] for x in batch]
    X2 = np.array([read_img(test_path + x) for x in X2])

    pred = model.predict([X1, X2]).ravel().tolist()
    predictions += pred

submission['is_related'] = predictions

submission.to_csv("vgg_face.csv", index=False)
# Out:
# 151it [15:59,  3.80s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-a430ae7e0591> in <module>
#      19     X2 = np.array([read_img(test_path + x) for x in X2])
#      20
# ---> 21     pred = model.predict([X1, X2]).ravel().tolist()
#      22     predictions += pred
#      23
#
# ~/Library/Python/3.7/lib/python/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# ~/Library/Python/3.7/lib/python/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
